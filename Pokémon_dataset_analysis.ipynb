# %% [markdown]
# # Acesso aos dados

# %%
# Importar as bibliotecas
import pandas as pd # para trabalhar com dataframes
import seaborn as sns # para visualização de dados / gráficos
import matplotlib.pyplot as plt # para visualização de dados / gráficos

# %%
# Acessar os dados do dataframe
df = pd.read_csv('pokemon.csv')

# %% [markdown]
# # Conhecendo os dados do dataframe

# %%
# Verificando o nome das colunas
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
# Exibir as 5 primeiras linhas do dataframe
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
# Informações gerais
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
# Quantidades de linhas e colunas iniciais
df.shape
# Out:
# (801, 41)

# %% [markdown]
# # Data cleaning

# %%
# Apagando colunas que não vão ser usadas
df = df.drop(columns=['base_egg_steps', 'base_happiness', 'japanese_name', 'base_total'])
#Verificando se foram apagadas
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
# Reordenando colunas
df = df[['pokedex_number', 'name', 'generation', 'type1', 'type2', 'hp',
              'attack', 'defense', 'speed', 'sp_attack', 'sp_defense', 'height_m',
              'weight_kg', 'percentage_male', 'experience_growth', 'capture_rate',
              'classfication', 'is_legendary', 'abilities', 'against_bug', 'against_dark',
              'against_dragon','against_electric', 'against_fairy', 'against_fight',
              'against_fire', 'against_flying', 'against_ghost', 'against_grass',
              'against_ground', 'against_ice', 'against_normal', 'against_poison',
              'against_psychic', 'against_rock', 'against_steel', 'against_water']]
# Verificando a ordem
df.columns
# Out:
# Index(['pokedex_number', 'name', 'generation', 'type1', 'type2', 'hp',
#        'attack', 'defense', 'speed', 'sp_attack', 'sp_defense', 'height_m',
#        'weight_kg', 'percentage_male', 'experience_growth', 'capture_rate',
#        'classfication', 'is_legendary', 'abilities', 'against_bug',
#        'against_dark', 'against_dragon', 'against_electric', 'against_fairy',
#        'against_fight', 'against_fire', 'against_flying', 'against_ghost',
#        'against_grass', 'against_ground', 'against_ice', 'against_normal',
#        'against_poison', 'against_psychic', 'against_rock', 'against_steel',
#        'against_water'],
#       dtype='object')

# %%
# Renomeando as colunas:
df = df.rename({'pokedex_number':'n pokedex', 'name': 'nome', 'generation':'geração', 'type1':'tipo 1', 'type2':'tipo 2', 'hp':'vida',
       'attack':'ataque', 'defense':'defesa', 'speed':'velocidade', 'sp_attack':'sp ataque', 'sp_defense': 'sp defesa', 'height_m':'altura m',
       'weight_kg': 'peso kg', 'percentage_male':'% macho', 'experience_growth':'xp evolução', 'capture_rate':'taxa de captura',
       'classfication':'classificação', 'is_legendary':'lendário', 'abilities':'habilidades', 'against_bug':'contra inseto',
       'against_dark':'contra escuridão', 'against_dragon':'contra dragão', 'against_electric':'contra elétrico', 'against_fairy':'contra fada',
       'against_fight':'contra lutador', 'against_fire':'contra fogo', 'against_flying':'contra voador', 'against_ghost': 'contra fantasma',
       'against_grass':'contra planta', 'against_ground':'contra terra', 'against_ice':'contra gelo', 'against_normal':'contra normal',
       'against_poison':'contra venenoso', 'against_psychic':'contra psíquico', 'against_rock':'contra pedra', 'against_steel':'contra aço',
       'against_water':'contra água'}, axis=1)
# Verificando as alterações
df.columns
# Out:
# Index(['n pokedex', 'nome', 'geração', 'tipo 1', 'tipo 2', 'vida', 'ataque',
#        'defesa', 'velocidade', 'sp ataque', 'sp defesa', 'altura m', 'peso kg',
#        '% macho', 'xp evolução', 'taxa de captura', 'classificação',
#        'lendário', 'habilidades', 'contra inseto', 'contra escuridão',
#        'contra dragão', 'contra elétrico', 'contra fada', 'contra lutador',
#        'contra fogo', 'contra voador', 'contra fantasma', 'contra planta',
#        'contra terra', 'contra gelo', 'contra normal', 'contra venenoso',
#        'contra psíquico', 'contra pedra', 'contra aço', 'contra água'],
#       dtype='object')

# %% [markdown]
# ## Renomeando itens das colunas

# %% [markdown]
# ### Coluna tipo 1

# %%
# Identificando valores unicos da coluna "tipo 1"
df['tipo 1'].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
# Renomeando valores da coluna "tipo 1"
df['tipo 1'] = df['tipo 1'].replace({'grass':'planta', 'fire':'fogo', 'water':'água', 'bug':'inseto', 'normal':'normal', 'poison':'venenoso', 'electric':'elétrico',
       'ground':'terra', 'fairy':'fada', 'fighting':'lutador', 'psychic':'psíquico', 'rock':'pedra', 'ghost':'fantasma', 'ice':'gelo',
       'dragon':'dragão', 'dark':'escuridão', 'steel':'aço', 'flying':'voador'})
# Verificando as alterações
df['tipo 1'].unique()
# Out:
# array(['planta', 'fogo', 'água', 'inseto', 'normal', 'venenoso',
#        'elétrico', 'terra', 'fada', 'lutador', 'psíquico', 'pedra',
#        'fantasma', 'gelo', 'dragão', 'escuridão', 'aço', 'voador'],
#       dtype=object)

# %% [markdown]
# ### Coluna tipo 2

# %%
# Identificando valores unicos da coluna "tipo 1"
df['tipo 2'].unique()
# Out:
# array(['poison', nan, 'flying', 'dark', 'electric', 'ice', 'ground',
#        'fairy', 'grass', 'fighting', 'psychic', 'steel', 'fire', 'rock',
#        'water', 'dragon', 'ghost', 'bug', 'normal'], dtype=object)

# %%
# Renomeando os valores da coluna "tipo 2"
df['tipo 2'] = df['tipo 2'].replace({'poison':'venenoso', 'flying':'voador', 'dark':'escuridão', 'electric':'elétrico', 'ice':'gelo', 'ground':'terra',
       'fairy':'fada', 'grass':'planta', 'fighting':'lutador', 'psychic':'psíquico', 'steel':'aço', 'fire':'fogo', 'rock':'pedra',
       'water':'água', 'dragon':'dragão', 'ghost':'fantasma', 'bug':'inseto', 'normal':'normal'})
# Verificando as alterações
df['tipo 2'].unique()
# Out:
# array(['venenoso', nan, 'voador', 'escuridão', 'elétrico', 'gelo',
#        'terra', 'fada', 'planta', 'lutador', 'psíquico', 'aço', 'fogo',
#        'pedra', 'água', 'dragão', 'fantasma', 'inseto', 'normal'],
#       dtype=object)

# %% [markdown]
# ### Coluna Lendários

# %%
# Identificando valores unicos da coluna "lendário"
df['lendário'].unique()
# Out:
# array([0, 1])

# %%
# Renomeando os valores da coluna "lendário"
df['lendário'] = df['lendário'].replace({0:'False', 1:'True'})
# Verificando as alterações
df['lendário'].unique()
# Out:
# array(['False', 'True'], dtype=object)

# %% [markdown]
# ### Coluna classificação

# %%
# Identificando valores unicos da coluna "classificação"
df['classificação'].unique()
# Out:
# array(['Seed Pokémon', 'Lizard Pokémon', 'Flame Pokémon',
#        'Tiny Turtle Pokémon', 'Turtle Pokémon', 'Shellfish Pokémon',
#        'Worm Pokémon', 'Cocoon Pokémon', 'Butterfly Pokémon',
#        'Hairy Pokémon', 'Poison Bee Pokémon', 'Tiny Bird Pokémon',
#        'Bird Pokémon', 'Mouse Pokémon', 'Beak Pokémon', 'Snake Pokémon',
#        'Cobra Pokémon', 'Poison Pin Pokémon', 'Drill Pokémon',
#        'Fairy Pokémon', 'Fox Pokémon', 'Balloon Pokémon', 'Bat Pokémon',
#        'Weed Pokémon', 'Flower Pokémon', 'Mushroom Pokémon',
#        'Insect Pokémon', 'Poison Moth Pokémon', 'Mole Pokémon',
#        'Scratch Cat Pokémon', 'Classy Cat Pokémon', 'Duck Pokémon',
#        'Pig Monkey Pokémon', 'Puppy Pokémon', 'Legendary Pokémon',
#        'Tadpole Pokémon', 'Psi Pokémon', 'Superpower Pokémon',
#        'Flycatcher Pokémon', 'Jellyfish Pokémon', 'Rock Pokémon',
#        'Megaton Pokémon', 'Fire Horse Pokémon', 'Dopey Pokémon',
# ...

# %%
# Renomeando os valores da coluna "classificação"
df['classificação'] = df['classificação'].replace(
    {'Seed Pokémon': 'Pokémon Semente',
    'Lizard Pokémon': 'Pokémon Lagarto',
    'Flame Pokémon': 'Pokémon de Chama',
    'Tiny Turtle Pokémon': 'Pokémon Tartaruguinha',
    'Turtle Pokémon': 'Pokémon Tartaruga',
    'Shellfish Pokémon': 'Pokémon Marisco',
    'Worm Pokémon': 'Pokémon Verme',
    'Cocoon Pokémon': 'Pokémon Casulo',
    'Butterfly Pokémon': 'Pokémon Borboleta',
    'Hairy Pokémon': 'Pokémon Peludo',
    'Poison Bee Pokémon': 'Pokémon Abelha Venenosa',
    'Tiny Bird Pokémon': 'Pokémon Passarinho',
    'Bird Pokémon': 'Pokémon Pássaro',
    'Mouse Pokémon': 'Pokémon Rato',
    'Beak Pokémon': 'Pokémon Bico',
    'Snake Pokémon': 'Pokémon Cobra',
    'Cobra Pokémon': 'Pokémon Naja',
    'Poison Pin Pokémon': 'Pokémon Pino Venenoso',
    'Drill Pokémon': 'Pokémon Broca',
    'Fairy Pokémon': 'Pokémon Fada',
    'Fox Pokémon': 'Pokémon Raposa',
    'Balloon Pokémon': 'Pokémon Balão',
    'Bat Pokémon': 'Pokémon Morcego',
    'Weed Pokémon': 'Pokémon Erva',
    'Flower Pokémon': 'Pokémon Flor',
    'Mushroom Pokémon': 'Pokémon Cogumelo',
    'Insect Pokémon': 'Pokémon Inseto',
    'Poison Moth Pokémon': 'Pokémon Mariposa Venenosa',
    'Mole Pokémon': 'Pokémon Toupeira',
    'Scratch Cat Pokémon': 'Pokémon Gato Arranhão',
    'Classy Cat Pokémon': 'Pokémon Gato Elegante',
    'Duck Pokémon': 'Pokémon Pato',
    'Pig Monkey Pokémon': 'Pokémon Macaco Porco',
    'Puppy Pokémon': 'Pokémon Cachorro',
    'Legendary Pokémon': 'Pokémon Lendário',
    'Tadpole Pokémon': 'Pokémon Girino',
    'Psi Pokémon': 'Pokémon Psi',
    'Superpower Pokémon': 'Pokémon Superpoderoso',
    'Flycatcher Pokémon': 'Pokémon Apanhador de Mosca',
    'Jellyfish Pokémon': 'Pokémon Água-viva',
    'Rock Pokémon': 'Pokémon Rocha',
    'Megaton Pokémon': 'Pokémon Megaton',
    'Fire Horse Pokémon': 'Pokémon Cavalo de Fogo',
    'Dopey Pokémon': 'Pokémon Tonto',
    'Hermit Crab Pokémon': 'Pokémon Caranguejo Eremita',
    'Magnet Pokémon': 'Pokémon Ímã',
    'Wild Duck Pokémon': 'Pokémon Pato Selvagem',
    'Twin Bird Pokémon': 'Pokémon Pássaro Gêmeo',
    'Triple Bird Pokémon': 'Pokémon Pássaro Triplo',
    'Sea Lion Pokémon': 'Pokémon Leão Marinho',
    'Sludge Pokémon': 'Pokémon Lama',
    'Bivalve Pokémon': 'Pokémon Bivalve',
    'Gas Pokémon': 'Pokémon Gás',
    'Shadow Pokémon': 'Pokémon Sombra',
    'Rock Snake Pokémon': 'Pokémon Serpente de Rocha',
    'Hypnosis Pokémon': 'Pokémon Hipnose',
    'River Crab Pokémon': 'Pokémon Caranguejo de Rio',
    'Pincer Pokémon': 'Pokémon Pinça',
    'Ball Pokémon': 'Pokémon Bola',
    'Egg Pokémon': 'Pokémon Ovo',
    'Coconut Pokémon': 'Pokémon Coco',
    'Lonely Pokémon': 'Pokémon Solitário',
    'Bone Keeper Pokémon': 'Pokémon Guarda de Ossos',
    'Kicking Pokémon': 'Pokémon Chutador',
    'Punching Pokémon': 'Pokémon Socador',
    'Licking Pokémon': 'Pokémon Lambedor',
    'Poison Gas Pokémon': 'Pokémon Gás Venenoso',
    'Spikes Pokémon': 'Pokémon Espinhos',
    'Vine Pokémon': 'Pokémon Vinha',
    'Parent Pokémon': 'Pokémon Parente',
    'Dragon Pokémon': 'Pokémon Dragão',
    'Goldfish Pokémon': 'Pokémon Peixe Dourado',
    'Starshape Pokémon': 'Pokémon Estrela',
    'Mysterious Pokémon': 'Pokémon Misterioso',
    'Barrier Pokémon': 'Pokémon Barreira',
    'Mantis Pokémon': 'Pokémon Louva-a-deus',
    'Humanshape Pokémon': 'Pokémon Forma Humana',
    'Electric Pokémon': 'Pokémon Elétrico',
    'Spitfire Pokémon': 'Pokémon Arremesso de Fogo',
    'Stagbeetle Pokémon': 'Pokémon Besouro-de-chifre',
    'Wild Bull Pokémon': 'Pokémon Touro Selvagem',
    'Fish Pokémon': 'Pokémon Peixe',
    'Atrocious Pokémon': 'Pokémon Atroz',
    'Transport Pokémon': 'Pokémon de Transporte',
    'Transform Pokémon': 'Pokémon Transformação',
    'Evolution Pokémon': 'Pokémon Evolução',
    'Bubble Jet Pokémon': 'Pokémon Jato de Bolhas',
    'Lightning Pokémon': 'Pokémon Relâmpago',
    'Virtual Pokémon': 'Pokémon Virtual',
    'Spiral Pokémon': 'Pokémon Espiral',
    'Fossil Pokémon': 'Pokémon Fóssil',
    'Sleeping Pokémon': 'Pokémon Dorminhoco',
    'Freeze Pokémon': 'Pokémon Congelamento',
    'Genetic Pokémon': 'Pokémon Genético',
    'New Species Pokémon': 'Pokémon Nova Espécie',
    'Leaf Pokémon': 'Pokémon Folha',
    'Herb Pokémon': 'Pokémon Erva',
    'Fire Mouse Pokémon': 'Pokémon Rato de Fogo',
    'Volcano Pokémon': 'Pokémon Vulcão',
    'Big Jaw Pokémon': 'Pokémon Mandíbula Grande',
    'Scout Pokémon': 'Pokémon Explorador',
    'Long Body Pokémon': 'Pokémon Corpo Longo',
    'Owl Pokémon': 'Pokémon Coruja',
    'Five Star Pokémon': 'Pokémon Cinco Estrelas',
    'String Spit Pokémon': 'Pokémon Cuspe de Linha',
    'Long Leg Pokémon': 'Pokémon Perna Longa',
    'Angler Pokémon': 'Pokémon Pescador',
    'Light Pokémon': 'Pokémon Luz',
    'Tiny Mouse Pokémon': 'Pokémon Ratinho Pequeno',
    'Star Shape Pokémon': 'Pokémon Forma de Estrela',
    'Spike Ball Pokémon': 'Pokémon Bola de Espinhos',
    'Happiness Pokémon': 'Pokémon Felicidade',
    'Little Bird Pokémon': 'Pokémon Passarinho Pequeno',
    'Mystic Pokémon': 'Pokémon Místico',
    'Wool Pokémon': 'Pokémon Lã',
    'Aquamouse Pokémon': 'Pokémon Rato Aquático',
    'Aquarabbit Pokémon': 'Pokémon Coelho Aquático',
    'Imitation Pokémon': 'Pokémon Imitação',
    'Frog Pokémon': 'Pokémon Sapo',
    'Cottonweed Pokémon': 'Pokémon Algodão',
    'Long Tail Pokémon': 'Pokémon Cauda Longa',
    'Sun Pokémon': 'Pokémon Sol',
    'Clear Wing Pokémon': 'Pokémon Asa Clara',
    'Water Fish Pokémon': 'Pokémon Peixe Aquático',
    'Moonlight Pokémon': 'Pokémon Luz Lunar',
    'Darkness Pokémon': 'Pokémon Escuridão',
    'Royal Pokémon': 'Pokémon Real',
    'Screech Pokémon': 'Pokémon Grito Estridente',
    'Symbol Pokémon': 'Pokémon Símbolo',
    'Patient Pokémon': 'Pokémon Paciente',
    'Long Neck Pokémon': 'Pokémon Pescoço Longo',
    'Bagworm Pokémon': 'Pokémon Saco de Verme',
    'Land Snake Pokémon': 'Pokémon Cobra Terrestre',
    'Flyscorpion Pokémon': 'Pokémon Escorpião Voador',
    'Iron Snake Pokémon': 'Pokémon Cobra de Ferro',
    'Mold Pokémon': 'Pokémon Mofo',
    'Singlehorn Pokémon': 'Pokémon Único Chifre',
    'Sharp Claw Pokémon': 'Pokémon Garra Afiada',
    'Little Bear Pokémon': 'Pokémon Ursinho',
    'Hibernator Pokémon': 'Pokémon Hibernador',
    'Lava Pokémon': 'Pokémon Lava',
    'Pig Pokémon': 'Pokémon Porco',
    'Swine Pokémon': 'Pokémon Suíno',
    'Coral Pokémon': 'Pokémon Coral',
    'Jet Pokémon': 'Pokémon Jato',
    'Delivery Pokémon': 'Pokémon Entrega',
    'Kite Pokémon': 'Pokémon Pipa',
    'Armor Bird Pokémon': 'Pokémon Pássaro Armado',
    'Dark Pokémon': 'Pokémon Sombrio',
    'Long Nose Pokémon': 'Pokémon Nariz Longo',
    'Armor Pokémon': 'Pokémon Armadura',
    'Big Horn Pokémon': 'Pokémon Grande Chifre',
    'Painter Pokémon': 'Pokémon Pintor',
    'Scuffle Pokémon': 'Pokémon Confusão',
    'Handstand Pokémon': 'Pokémon Apoio de Mão',
    'Kiss Pokémon': 'Pokémon Beijo',
    'Live Coal Pokémon': 'Pokémon Carvão Vivo',
    'Milk Cow Pokémon': 'Pokémon Vaca de Leite',
    'Thunder Pokémon': 'Pokémon Trovão',
    'Aurora Pokémon': 'Pokémon Aurora',
    'Rock Skin Pokémon': 'Pokémon Pele de Rocha',
    'Hard Shell Pokémon': 'Pokémon Casca Dura',
    'Diving Pokémon': 'Pokémon Mergulhador',
    'Rainbow Pokémon': 'Pokémon Arco-íris',
    'Time Travel Pokémon': 'Pokémon Viagem no Tempo',
    'Wood Gecko Pokémon': 'Pokémon Geco de Madeira',
    'Forest Pokémon': 'Pokémon Floresta',
    'Chick Pokémon': 'Pokémon Pintinho',
    'Young Fowl Pokémon': 'Pokémon Ave Jovem',
    'Blaze Pokémon': 'Pokémon Chama Ardente',
    'Mud Fish Pokémon': 'Pokémon Peixe de Lama',
    'Bite Pokémon': 'Pokémon Mordida',
    'Tiny Racoon Pokémon': 'Pokémon Guaxinim Pequeno',
    'Rush Pokémon': 'Pokémon Pressa',
    'Water Weed Pokémon': 'Pokémon Erva Aquática',
    'Jolly Pokémon': 'Pokémon Alegre',
    'Carefree Pokémon': 'Pokémon Despreocupado',
    'Acorn Pokémon': 'Pokémon Bolota',
    'Wily Pokémon': 'Pokémon Astuto',
    'Wickid Pokémon': 'Pokémon Malvado',
    'TinySwallow Pokémon': 'Pokémon Andorinha Minúscula',
    'Swallow Pokémon': 'Pokémon Andorinha',
    'Seagull Pokémon': 'Pokémon Gaivota',
    'Water Bird Pokémon': 'Pokémon Pássaro Aquático',
    'Feeling Pokémon': 'Pokémon Sentimento',
    'Emotion Pokémon': 'Pokémon Emoção',
    'Embrace Pokémon': 'Pokémon Abraço',
    'Pond Skater Pokémon': 'Pokémon Escorregador de Lagoa',
    'Eyeball Pokémon': 'Pokémon Olho',
    'Slacker Pokémon': 'Pokémon Preguiçoso',
    'Wild Monkey Pokémon': 'Pokémon Macaco Selvagem',
    'Lazy Pokémon': 'Pokémon Preguiça',
    'Trainee Pokémon': 'Pokémon Estagiário',
    'Ninja Pokémon': 'Pokémon Ninja',
    'Shed Pokémon': 'Pokémon Desprezado',
    'Whisper Pokémon': 'Pokémon Sussurro',
    'Big Voice Pokémon': 'Pokémon Voz Alta',
    'Loud Noise Pokémon': 'Pokémon Barulhento',
    'Guts Pokémon': 'Pokémon Coragem',
    'Arm Thrust Pokémon': 'Pokémon Empurrão de Braço',
    'Polka Dot Pokémon': 'Pokémon Bolinha',
    'Compass Pokémon': 'Pokémon Bússola',
    'Kitten Pokémon': 'Pokémon Gatinho',
    'Prim Pokémon': 'Pokémon Prim',
    'Deceiver Pokémon': 'Pokémon Enganador',
    'Iron Armor Pokémon': 'Pokémon Armadura de Ferro',
    'Meditate Pokémon': 'Pokémon Meditação',
    'Discharge Pokémon': 'Pokémon Descarga',
    'Cheering Pokémon': 'Pokémon Incentivo',
    'Firefly Pokémon': 'Pokémon Vagalume',
    'Thorn Pokémon': 'Pokémon Espinho',
    'Stomach Pokémon': 'Pokémon Estômago',
    'Poison Bag Pokémon': 'Pokémon Saco de Veneno',
    'Savage Pokémon': 'Pokémon Selvagem',
    'Brutal Pokémon': 'Pokémon Brutal',
    'Ball Whale Pokémon': 'Pokémon Baleia de Bola',
    'Float Whale Pokémon': 'Pokémon Baleia Flutuante',
    'Numb Pokémon': 'Pokémon Entorpecente',
    'Eruption Pokémon': 'Pokémon Erupção',
    'Coal Pokémon': 'Pokémon Carvão',
    'Bounce Pokémon': 'Pokémon Quicante',
    'Manipulate Pokémon': 'Pokémon Manipulação',
    'Spot Panda Pokémon': 'Pokémon Panda com Manchas',
    'Ant Pit Pokémon': 'Pokémon Formigueiro',
    'Vibration Pokémon': 'Pokémon Vibração',
    'Cactus Pokémon': 'Pokémon Cacto',
    'Scarecrow Pokémon': 'Pokémon Espantalho',
    'Cotton Bird Pokémon': 'Pokémon Pássaro de Algodão',
    'Humming Pokémon': 'Pokémon Zumbido',
    'Cat Ferret Pokémon': 'Pokémon Gato Furão',
    'Fang Snake Pokémon': 'Pokémon Cobra de Presa',
    'Meteorite Pokémon': 'Pokémon Meteorito',
    'Whiskers Pokémon': 'Pokémon Bigode',
    'Ruffian Pokémon': 'Pokémon Vagabundo',
    'Rogue Pokémon': 'Pokémon Trapaceiro',
    'Clay Doll Pokémon': 'Pokémon Boneco de Argila',
    'Sea Lily Pokémon': 'Pokémon Lírio do Mar',
    'Barnacle Pokémon': 'Pokémon Craca',
    'Old Shrimp Pokémon': 'Pokémon Camarão Velho',
    'Plate Pokémon': 'Pokémon Placa',
    'Tender Pokémon': 'Pokémon Gentil',
    'Weather Pokémon': 'Pokémon Clima',
    'Color Swap Pokémon': 'Pokémon Troca de Cores',
    'Puppet Pokémon': 'Pokémon Boneco',
    'Marionette Pokémon': 'Pokémon Marionete',
    'Requiem Pokémon': 'Pokémon Réquiem',
    'Beckon Pokémon': 'Pokémon Atrair',
    'Fruit Pokémon': 'Pokémon Fruta',
    'Wind Chime Pokémon': 'Pokémon Sino de Vento',
    'Disaster Pokémon': 'Pokémon Desastre',
    'Bright Pokémon': 'Pokémon Brilhante',
    'Snow Hat Pokémon': 'Pokémon Chapéu de Neve',
    'Face Pokémon': 'Pokémon Rosto',
    'Clap Pokémon': 'Pokémon Aplauso',
    'Ball Roll Pokémon': 'Pokémon Rola Bola',
    'Ice Break Pokémon': 'Pokémon Quebra-gelo',
    'Deep Sea Pokémon': 'Pokémon Mar Profundo',
    'South Sea Pokémon': 'Pokémon Mar do Sul',
    'Longevity Pokémon': 'Pokémon Longevidade',
    'Rendezvous Pokémon': 'Pokémon Encontro',
    'Rock Head Pokémon': 'Pokémon Cabeça de Pedra',
    'Endurance Pokémon': 'Pokémon Resistência',
    'Iron Ball Pokémon': 'Pokémon Bola de Ferro',
    'Iron Claw Pokémon': 'Pokémon Garra de Ferro',
    'Iron Leg Pokémon': 'Pokémon Perna de Ferro',
    'Rock Peak Pokémon': 'Pokémon Pico de Rocha',
    'Iceberg Pokémon': 'Pokémon Icebergue',
    'Iron Pokémon': 'Pokémon Ferro',
    'Eon Pokémon': 'Pokémon Eon',
    'Sea Basin Pokémon': 'Pokémon Bacia Marinha',
    'Continent Pokémon': 'Pokémon Continente',
    'Sky High Pokémon': 'Pokémon Altura Máxima',
    'Wish Pokémon': 'Pokémon Desejo',
    'DNA Pokémon': 'Pokémon DNA',
    'Tiny Leaf Pokémon': 'Pokémon Folha Minúscula',
    'Grove Pokémon': 'Pokémon Bosque',
    'Chimp Pokémon': 'Pokémon Chimpanzé',
    'Playful Pokémon': 'Pokémon Brincalhão',
    'Penguin Pokémon': 'Pokémon Pinguim',
    'Emperor Pokémon': 'Pokémon Imperador',
    'Starling Pokémon': 'Pokémon Estorninho',
    'Predator Pokémon': 'Pokémon Predador',
    'Plump Mouse Pokémon': 'Pokémon Rato Rechonchudo',
    'Beaver Pokémon': 'Pokémon Castor',
    'Cricket Pokémon': 'Pokémon Grilo',
    'Flash Pokémon': 'Pokémon Flash',
    'Spark Pokémon': 'Pokémon Centelha',
    'Gleam Eyes Pokémon': 'Pokémon Olhos Cintilantes',
    'Bud Pokémon': 'Pokémon Brotinho',
    'Bouquet Pokémon': 'Pokémon Buquê',
    'Head Butt Pokémon': 'Pokémon Cabeçada',
    'Shield Pokémon': 'Pokémon Escudo',
    'Moth Pokémon': 'Pokémon Mariposa',
    'Tiny Bee Pokémon': 'Pokémon Abelha Minúscula',
    'Beehive Pokémon': 'Pokémon Colmeia',
    'EleSquirrel Pokémon': 'Pokémon Esquilo Elétrico',
    'Sea Weasel Pokémon': 'Pokémon Doninha do Mar',
    'Cherry Pokémon': 'Pokémon Cereja',
    'Blossom Pokémon': 'Pokémon Florada',
    'Sea Slug Pokémon': 'Pokémon Lesma Marinha',
    'Blimp Pokémon': 'Pokémon Dirigível',
    'Rabbit Pokémon': 'Pokémon Coelho',
    'Magical Pokémon': 'Pokémon Mágico',
    'Big Boss Pokémon': 'Pokémon Chefe Grande',
    'Catty Pokémon': 'Pokémon Gatuna',
    'Tiger Cat Pokémon': 'Pokémon Gato Tigre',
    'Bell Pokémon': 'Pokémon Sino',
    'Skunk Pokémon': 'Pokémon Doninha',
    'Bronze Pokémon': 'Pokémon Bronze',
    'Bronze Bell Pokémon': 'Pokémon Sino de Bronze',
    'Bonsai Pokémon': 'Pokémon Bonsai',
    'Mime Pokémon': 'Pokémon Mímico',
    'Playhouse Pokémon': 'Pokémon Casinha de Bonecas',
    'Music Note Pokémon': 'Pokémon Nota Musical',
    'Forbidden Pokémon': 'Pokémon Proibido',
    'Land Shark Pokémon': 'Pokémon Tubarão Terrestre',
    'Cave Pokémon': 'Pokémon Caverna',
    'Mach Pokémon': 'Pokémon Machado',
    'Big Eater Pokémon': 'Pokémon Comilão',
    'Emanation Pokémon': 'Pokémon Emanação',
    'Aura Pokémon': 'Pokémon Aura',
    'Hippo Pokémon': 'Pokémon Hipopótamo',
    'Heavyweight Pokémon': 'Pokémon Pesado',
    'Scorpion Pokémon': 'Pokémon Escorpião',
    'Ogre Scorp Pokémon': 'Pokémon Escorpião Ogro',
    'Toxic Mouth Pokémon': 'Pokémon Boca Tóxica',
    'Bug Catcher Pokémon': 'Pokémon Caçador de Insetos',
    'Wing Fish Pokémon': 'Pokémon Peixe Asa',
    'Neon Pokémon': 'Pokémon Néon',
    'Frosted Tree Pokémon': 'Pokémon Árvore Gead',
    'Magnet Area Pokémon': 'Pokémon Área Magnética',
    'Thunderbolt Pokémon': 'Pokémon Raio Trovejante',
    'Blast Pokémon': 'Pokémon Explosão',
    'Jubilee Pokémon': 'Pokémon Jubileu',
    'Ogre Darner Pokémon': 'Pokémon Libélula Ogro',
    'Verdant Pokémon': 'Pokémon Verdoso',
    'Fresh Snow Pokémon': 'Pokémon Neve Fresca',
    'Fang Scorp Pokémon': 'Pokémon Escorpião Fang',
    'Twin Tusk Pokémon': 'Pokémon Presa Gêmea',
    'Blade Pokémon': 'Pokémon Lâmina',
    'Gripper Pokémon': 'Pokémon Agarrador',
    'Snow Land Pokémon': 'Pokémon Terra Nevosa',
    'Plasma Pokémon': 'Pokémon de Plasma',
    'Knowledge Pokémon': 'Pokémon do Conhecimento',
    'Willpower Pokémon': 'Pokémon da Força de Vontade',
    'Temporal Pokémon': 'Pokémon Temporal',
    'Spatial Pokémon': 'Pokémon Espacial',
    'Lava Dome Pokémon': 'Pokémon da Cúpula de Lava',
    'Colossal Pokémon': 'Pokémon Colossal',
    'Renegade Pokémon': 'Pokémon Renegado',
    'Lunar Pokémon': 'Pokémon Lunar',
    'Sea Drifter Pokémon': 'Pokémon Navegador do Mar',
    'Seafaring Pokémon': 'Pokémon Navegante',
    'Pitch-Black Pokémon': 'Pokémon Negrorrente',
    'Gratitude Pokémon': 'Pokémon da Gratidão',
    'Alpha Pokémon': 'Pokémon Alfa',
    'Victory Pokémon': 'Pokémon da Vitória',
    'Grass Snake Pokémon': 'Pokémon Serpente de Grama',
    'Regal Pokémon': 'Pokémon Régio',
    'Fire Pig Pokémon': 'Pokémon Porco de Fogo',
    'Mega Fire Pig Pokémon': 'Pokémon Porco de Fogo Mega',
    'Sea Otter Pokémon': 'Pokémon Lontra Marinha',
    'Discipline Pokémon': 'Pokémon Disciplinado',
    'Formidable Pokémon': 'Pokémon Formidável',
    'Lookout Pokémon': 'Pokémon Vigia',
    'Loyal Dog Pokémon': 'Pokémon Cão Leal',
    'Big-Hearted Pokémon': 'Pokémon de Grande Coração',
    'Devious Pokémon': 'Pokémon Desonesto',
    'Cruel Pokémon': 'Pokémon Cruel',
    'Grass Monkey Pokémon': 'Pokémon Macaco de Grama',
    'Thorn Monkey Pokémon': 'Pokémon Macaco de Espinhos',
    'High Temp Pokémon': 'Pokémon de Alta Temperatura',
    'Ember Pokémon': 'Pokémon de Brasa',
    'Spray Pokémon': 'Pokémon de Jato',
    'Geyser Pokémon': 'Pokémon do Gêiser',
    'Dream Eater Pokémon': 'Pokémon Devorador de Sonhos',
    'Drowsing Pokémon': 'Pokémon Sonolento',
    'Tiny Pigeon Pokémon': 'Pokémon Pombinho Minúsculo',
    'Wild Pigeon Pokémon': 'Pokémon Pomba Selvagem',
    'Proud Pokémon': 'Pokémon Orgulhoso',
    'Electrified Pokémon': 'Pokémon Eletrificado',
    'Mantle Pokémon': 'Pokémon Manto',
    'Ore Pokémon': 'Pokémon de Minério',
    'Compressed Pokémon': 'Pokémon Comprimido',
    'Courting Pokémon': 'Pokémon Cortejante',
    'Subterrene Pokémon': 'Pokémon Subterrâneo',
    'Hearing Pokémon': 'Pokémon Auditivo',
    'Muscular Pokémon': 'Pokémon Musculoso',
    'Judo Pokémon': 'Pokémon de Judô',
    'Karate Pokémon': 'Pokémon de Karatê',
    'Sewing Pokémon': 'Pokémon Costureiro',
    'Leaf-Wrapped Pokémon': 'Pokémon Enrolado em Folha',
    'Nurturing Pokémon': 'Pokémon Nutridor',
    'Centipede Pokémon': 'Pokémon Centopeia',
    'Curlipede Pokémon': 'Pokémon Encaracolado',
    'Megapede Pokémon': 'Pokémon Megapede',
    'Cotton Puff Pokémon': 'Pokémon de Algodão',
    'Windveiled Pokémon': 'Pokémon Velado pelo Vento',
    'Bulb Pokémon': 'Pokémon Bulbo',
    'Flowering Pokémon': 'Pokémon Florido',
    'Hostile Pokémon': 'Pokémon Hostil',
    'Desert Croc Pokémon': 'Pokémon Crocodilo do Deserto',
    'Intimidation Pokémon': 'Pokémon de Intimidação',
    'Zen Charm Pokémon': 'Pokémon Encanto Zen',
    'Blazing Pokémon': 'Pokémon Flamejante',
    'Rock Inn Pokémon': 'Pokémon Rocamar',
    'Stone Home Pokémon': 'Pokémon Casa de Pedra',
    'Shedding Pokémon': 'Pokémon que Muda de Pele',
    'Hoodlum Pokémon': 'Pokémon Vagabundo',
    'Avianoid Pokémon': 'Pokémon Avianóide',
    'Spirit Pokémon': 'Pokémon Espírito',
    'Coffin Pokémon': 'Pokémon Caixão',
    'Prototurtle Pokémon': 'Pokémon Prototartaruga',
    'First Bird Pokémon': 'Primeiro Pokémon Pássaro',
    'Trash Bag Pokémon': 'Pokémon Saco de Lixo',
    'Trash Heap Pokémon': 'Pokémon Monturo de Lixo',
    'Tricky Fox Pokémon': 'Pokémon Raposa Astuta',
    'Illusion Fox Pokémon': 'Pokémon Raposa Ilusória',
    'Chinchilla Pokémon': 'Pokémon Chinchila',
    'Scarf Pokémon': 'Pokémon Cachecol',
    'Fixation Pokémon': 'Pokémon Fixação',
    'Astral Body Pokémon': 'Pokémon Corpo Astral',
    'Cell Pokémon': 'Pokémon Célula',
    'Mitosis Pokémon': 'Pokémon Mitose',
    'Multiplying Pokémon': 'Pokémon Multiplicador',
    'White Bird Pokémon': 'Pokémon Pássaro Branco',
    'Icy Snow Pokémon': 'Pokémon Neve Gelada',
    'Snowstorm Pokémon': 'Pokémon Tempestade de Neve',
    'Season Pokémon': 'Pokémon Estação',
    'Sky Squirrel Pokémon': 'Pokémon Esquilo do Céu',
    'Clamping Pokémon': 'Pokémon Abraçador',
    'Cavalry Pokémon': 'Pokémon de Cavalaria',
    'Floating Pokémon': 'Pokémon Flutuante',
    'Caring Pokémon': 'Pokémon Cuidador',
    'Attaching Pokémon': 'Pokémon Agarrador',
    'EleSpider Pokémon': 'Pokémon EleAranha',
    'Thorn Seed Pokémon': 'Pokémon Semente de Espinho',
    'Thorn Pod Pokémon': 'Pokémon Vagem de Espinho',
    'Gear Pokémon': 'Pokémon Engrenagem',
    'EleFish Pokémon': 'Pokémon ElePeixe',
    'Cerebral Pokémon': 'Pokémon Cerebral',
    'Candle Pokémon': 'Pokémon Vela',
    'Lamp Pokémon': 'Pokémon Lâmpada',
    'Luring Pokémon': 'Pokémon Atrativo',
    'Tusk Pokémon': 'Pokémon Presa',
    'Axe Jaw Pokémon': 'Pokémon Mandíbula de Machado',
    'Chill Pokémon': 'Pokémon Gelo',
    'Freezing Pokémon': 'Pokémon Congelante',
    'Crystallizing Pokémon': 'Pokémon Cristalizador',
    'Snail Pokémon': 'Pokémon Caracol',
    'Shell Out Pokémon': 'Pokémon Fora da Concha',
    'Trap Pokémon': 'Pokémon Armadilha',
    'Martial Arts Pokémon': 'Pokémon de Artes Marciais',
    'Automaton Pokémon': 'Pokémon Autômato',
    'Sharp Blade Pokémon': 'Pokémon Lâmina Afiada',
    'Sword Blade Pokémon': 'Pokémon Lâmina de Espada',
    'Bash Buffalo Pokémon': 'Pokémon Búfalo de Investida',
    'Eaglet Pokémon': 'Pokémon Filhote de Águia',
    'Valiant Pokémon': 'Pokémon Valente',
    'Diapered Pokémon': 'Pokémon de Fraldas',
    'Bone Vulture Pokémon': 'Pokémon Abutre de Ossos',
    'Anteater Pokémon': 'Pokémon Tamanduá',
    'Iron Ant Pokémon': 'Pokémon Formiga de Ferro',
    'Irate Pokémon': 'Pokémon Irado',
    'Torch Pokémon': 'Pokémon Tocha',
    'Iron Will Pokémon': 'Pokémon de Vontade de Ferro',
    'Cavern Pokémon': 'Pokémon Caverna',
    'Grassland Pokémon': 'Pokémon Campo Gramado',
    'Cyclone Pokémon': 'Pokémon Ciclone',
    'Bolt Strike Pokémon': 'Pokémon Raio de Impacto',
    'Vast White Pokémon': 'Pokémon Branco Vasto',
    'Deep Black Pokémon': 'Pokémon Preto Profundo',
    'Abundance Pokémon': 'Pokémon da Abundância',
    'Boundary Pokémon': 'Pokémon Limite',
    'Colt Pokémon': 'Pokémon Potro',
    'Melody Pokémon': 'Pokémon Melodia',
    'Paleozoic Pokémon': 'Pokémon Paleozoico',
    'Spiky Nut Pokémon': 'Pokémon Noz Espinhosa',
    'Spiny Armor Pokémon': 'Pokémon Armadura Espinhosa',
    'Bubble Frog Pokémon': 'Pokémon Sapo de Bolha',
    'Digging Pokémon': 'Pokémon Escavador',
    'Tiny Robin Pokémon': 'Pokémon Pardal Pequeno',
    'Scorching Pokémon': 'Pokémon Abrasador',
    'Scatterdust Pokémon': 'Pokémon Poeira Espalhada',
    'Scale Pokémon': 'Pokémon Escama',
    'Lion Cub Pokémon': 'Pokémon Filhote de Leão',
    'Single Bloom Pokémon': 'Pokémon Flor Única',
    'Garden Pokémon': 'Pokémon Jardim',
    'Mount Pokémon': 'Pokémon Montanha',
    'Daunting Pokémon': 'Pokémon Intimidador',
    'Poodle Pokémon': 'Pokémon Poodle',
    'Restraint Pokémon': 'Pokémon Restrição',
    'Constraint Pokémon': 'Pokémon Restrição',
    'Sword Pokémon': 'Pokémon Espada',
    'Royal Sword Pokémon': 'Pokémon Espada Real',
    'Perfume Pokémon': 'Pokémon Perfume',
    'Fragrance Pokémon': 'Pokémon Fragrância',
    'Cotton Candy Pokémon': 'Pokémon Algodão Doce',
    'Meringue Pokémon': 'Pokémon Merengue',
    'Revolving Pokémon': 'Pokémon Giratório',
    'Overturning Pokémon': 'Pokémon Reversão',
    'Two-Handed Pokémon': 'Pokémon de Duas Mãos',
    'Collective Pokémon': 'Pokémon Coletivo',
    'Mock Kelp Pokémon': 'Pokémon Alga Falsa',
    'Water Gun Pokémon': 'Pokémon Pistola de Água',
    'Howitzer Pokémon': 'Pokémon Obus',
    'Generator Pokémon': 'Pokémon Gerador',
    'Royal Heir Pokémon': 'Pokémon Herdeiro Real',
    'Despot Pokémon': 'Pokémon Destruidor',
    'Tundra Pokémon': 'Pokémon Tundra',
    'Intertwining Pokémon': 'Pokémon Entrelaçado',
    'Wrestling Pokémon': 'Pokémon Lutador',
    'Antenna Pokémon': 'Pokémon Antena',
    'Jewel Pokémon': 'Pokémon Joia',
    'Soft Tissue Pokémon': 'Pokémon Tecido Macio',
    'Key Ring Pokémon': 'Pokémon Chaveiro',
    'Stump Pokémon': 'Pokémon Toco',
    'Elder Tree Pokémon': 'Pokémon Árvore Anciã',
    'Pumpkin Pokémon': 'Pokémon Abóbora',
    'Ice Chunk Pokémon': 'Pokémon Pedaço de Gelo',
    'Sound Wave Pokémon': 'Pokémon Onda Sonora',
    'Life Pokémon': 'Pokémon Vida',
    'Destruction Pokémon': 'Pokémon Destruição',
    'Order Pokémon': 'Pokémon Ordem',
    'Mischief Pokémon (Confined)': 'Pokémon Malícia (Contido)',
    'Djinn Pokémonn (Unbound)': 'Pokémon Gênio (Livre)',
    'Steam Pokémon': 'Pokémon Vapor',
    'Grass Quill Pokémon': 'Pokémon Espinho de Grama',
    'Blade Quill Pokémon': 'Pokémon Espinho de Lâmina',
    'Arrow Quill Pokémon': 'Pokémon Espinho de Flecha',
    'Fire Cat Pokémon': 'Pokémon Gato de Fogo',
    'Heel Pokémon': 'Pokémon Calcanhar',
    'Pop Star Pokémon': 'Pokémon Estrela Pop',
    'Soloist Pokémon': 'Pokémon Solista',
    'Woodpecker Pokémon': 'Pokémon Pica-Pau',
    'Bugle Beak Pokémon': 'Pokémon Bico de Clarim',
    'Cannon Pokémon': 'Pokémon Canhão',
    'Loitering Pokémon': 'Pokémon Vadiando',
    'Stakeout Pokémon': 'Pokémon Vigia',
    'Larva Pokémon': 'Pokémon Larva',
    'Battery Pokémon': 'Pokémon Bateria',
    'Stag Beetle Pokémon': 'Pokémon Besouro-Cervo',
    'Boxing Pokémon': 'Pokémon Boxeador',
    'Woolly Crab Pokémon': 'Pokémon Caranguejo Peludo',
    'Dancing Pokémon': 'Pokémon Dançarino',
    'Bee Fly Pokémon': 'Pokémon Mosca Abelha',
    'Wolf Pokémon': 'Pokémon Lobo',
    'Small Fry Pokémon': 'Pokémon Miúdo',
    'Brutal Star Pokémon': 'Pokémon Estrela Brutal',
    'Donkey Pokémon': 'Pokémon Burro',
    'Draft Horse Pokémon': 'Pokémon Cavalo de Trabalho',
    'Water Bubble Pokémon': 'Pokémon Bolha de Água',
    'Sickle Grass Pokémon': 'Pokémon Grama Foice',
    'Bloom Sickle Pokémon': 'Pokémon Grama Flor',
    'Illuminating Pokémon': 'Pokémon Iluminador',
    'Toxic Lizard Pokémon': 'Pokémon Lagarto Tóxico',
    'Flailing Pokémon': 'Pokémon Agitador',
    'Strong Arm Pokémon': 'Pokémon Braço Forte',
    'Posy Picker Pokémon': 'Pokémon Coletor de Buquê',
    'Sage Pokémon': 'Pokémon Sábio',
    'Teamwork Pokémon': 'Pokémon Trabalho em Equipe',
    'Turn Tail Pokémon': 'Pokémon de Reta',
    'Hard Scale Pokémon': 'Pokémon Escama Dura',
    'Sand Heap Pokémon': 'Pokémon Montículo de Areia',
    'Sand Castle Pokémon': 'Pokémon Castelo de Areia',
    'Sea Cucumber Pokémon': 'Pokémon Pepino do Mar',
    'Synthetic Pokémon': 'Pokémon Sintético',
    'Meteor Pokémon': 'Pokémon Meteoro',
    'Blast Turtle Pokémon': 'Pokémon Tartaruga Explosiva',
    'Roly-Poly Pokémon': 'Pokémon Bolinha',
    'Disguise Pokémon': 'Pokémon Disfarce',
    'Gnash Teeth Pokémon': 'Pokémon Dentes Rachados',
    'Placid Pokémon': 'Pokémon Plácido',
    'Sea Creeper Pokémon': 'Pokémon Rastejador Marinho',
    'Scaly Pokémon': 'Pokémon Escamoso',
    'Land Spirit Pokémon': 'Pokémon Espírito Terrestre',
    'Nebula Pokémon': 'Pokémon Nebulosa',
    'Protostar Pokémon': 'Pokémon Protostar',
    'Sunne Pokémon': 'Pokémon Sol',
    'Moone Pokémon': 'Pokémon Lua',
    'Parasite Pokémon': 'Pokémon Parasita',
    'Swollen Pokémon': 'Pokémon Inchado',
    'Lissome Pokémon': 'Pokémon Elegante',
    'Glowing Pokémon': 'Pokémon Brilhante',
    'Launch Pokémon': 'Pokémon Lançamento',
    'Drawn Sword Pokémon': 'Pokémon Espada Desembainhada',
    'Junkivore Pokémon': 'Pokémon Lixo',
    'Prism Pokémon': 'Pokémon Prisma',
    'Artificial Pokémon': 'Pokémon Artificial'})
# Verificando as alterações
df['classificação'].unique()
# Out:
# array(['Pokémon Semente', 'Pokémon Lagarto', 'Pokémon de Chama',
#        'Pokémon Tartaruguinha', 'Pokémon Tartaruga', 'Pokémon Marisco',
#        'Pokémon Verme', 'Pokémon Casulo', 'Pokémon Borboleta',
#        'Pokémon Peludo', 'Pokémon Abelha Venenosa', 'Pokémon Passarinho',
#        'Pokémon Pássaro', 'Pokémon Rato', 'Pokémon Bico', 'Pokémon Cobra',
#        'Pokémon Naja', 'Pokémon Pino Venenoso', 'Pokémon Broca',
#        'Pokémon Fada', 'Pokémon Raposa', 'Pokémon Balão',
#        'Pokémon Morcego', 'Pokémon Erva', 'Pokémon Flor',
#        'Pokémon Cogumelo', 'Pokémon Inseto', 'Pokémon Mariposa Venenosa',
#        'Pokémon Toupeira', 'Pokémon Gato Arranhão',
#        'Pokémon Gato Elegante', 'Pokémon Pato', 'Pokémon Macaco Porco',
#        'Pokémon Cachorro', 'Pokémon Lendário', 'Pokémon Girino',
#        'Pokémon Psi', 'Pokémon Superpoderoso',
#        'Pokémon Apanhador de Mosca', 'Pokémon Água-viva', 'Pokémon Rocha',
# ...

# %% [markdown]
# # Adicionado colunas "Total" e "md atr"

# %%
# Adicionando colunas
df['total atr'] = df['vida'] + df['ataque'] + df['defesa'] + df['velocidade'] + df['sp ataque'] + df['sp defesa']
df['md atr'] = df['total atr'] / 6
# verificando alterações
df['total atr']
df['md atr']
# Out:
# 0       53.000000
# 1       67.500000
# 2      104.166667
# 3       51.500000
# 4       67.500000
#           ...
# 796     95.000000
# 797     95.000000
# 798     95.000000
# 799    100.000000
# 800    100.000000
# Name: md atr, Length: 801, dtype: float64

# %%
# Reordenando as colunas novas
df = df[['n pokedex', 'nome', 'geração', 'tipo 1', 'tipo 2', 'vida', 'ataque',
       'defesa', 'velocidade', 'sp ataque', 'sp defesa', 'total atr', 'md atr', 'altura m', 'peso kg',
       '% macho', 'xp evolução', 'taxa de captura', 'classificação',
       'lendário', 'habilidades', 'contra inseto', 'contra escuridão',
       'contra dragão', 'contra elétrico', 'contra fada', 'contra lutador',
       'contra fogo', 'contra voador', 'contra fantasma', 'contra planta',
       'contra terra', 'contra gelo', 'contra normal', 'contra venenoso',
       'contra psíquico', 'contra pedra', 'contra aço', 'contra água']]
df.columns
# Out:
# Index(['n pokedex', 'nome', 'geração', 'tipo 1', 'tipo 2', 'vida', 'ataque',
#        'defesa', 'velocidade', 'sp ataque', 'sp defesa', 'total atr', 'md atr',
#        'altura m', 'peso kg', '% macho', 'xp evolução', 'taxa de captura',
#        'classificação', 'lendário', 'habilidades', 'contra inseto',
#        'contra escuridão', 'contra dragão', 'contra elétrico', 'contra fada',
#        'contra lutador', 'contra fogo', 'contra voador', 'contra fantasma',
#        'contra planta', 'contra terra', 'contra gelo', 'contra normal',
#        'contra venenoso', 'contra psíquico', 'contra pedra', 'contra aço',
#        'contra água'],
#       dtype='object')

# %%
# Ajuste no valor da coluna "Taxa de captura"
df['taxa de captura'] = df['taxa de captura'].replace({'30 (Meteorite)255 (Core)':30})

# %% [markdown]
# # Plotagem

# %%
# Tipo de pokémon por média de atributo
# Gráfico para descobrir quais os tipos de pokémons mais forte.
eixo_x = df['tipo 1']
eixo_y = df['md atr']
titulo = 'Tipo de pokémon por média de atributos'
label_x = 'Tipos de pokémons'
label_y = 'Média dos atributos'

plt.figure(figsize=(16, 4))
plt.title(titulo)
plt.xlabel(label_x)
plt.ylabel(label_y)
plt.bar(eixo_x, eixo_y, color='#1C98A6')
plt.show()

# %%
# Quantidades de pokémons por tipo
# Gráfico para descobrir quais tipos de pokemon possuem uma quantidade maior.
eixo_x = df['tipo 1']
titulo = 'Quantidades de pokémons por tipo'
label_x = 'Tipos de pokémons'
label_y = 'Quantidade'

plt.figure(figsize=(16, 4))
plt.title(titulo)
plt.xlabel(label_x)
plt.ylabel(label_y)
plt.hist(df['tipo 1'], bins=37, color='#1C98A6')
plt.show()

# %%
# Ataque e defesa por tipo de pokémon
# Gráfico para descobrir o ataque a defesa de cada tipo de pokemon.
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.ylabel('Tipo de pokémon')
plt.xlabel('Defesa/Ataque')
plt.title('Ataque e defesa por tipo de pokémon')
sns.set_color_codes("pastel")
sns.barplot(x=df['ataque'], y=df['tipo 1'], data=df,
            label="Ataque", color="#F28705", errorbar=None)
sns.barplot(x=df['defesa'], y=df['tipo 1'], data=df,
            label="Defesa", color="#F2E205", errorbar=None)
# Out:
# <Axes: title={'center': 'Ataque e defesa por tipo de pokémon'}, xlabel='Defesa/Ataque', ylabel='Tipo de pokémon'>

# %%
# Relação entre peso e altura dos pokémons
# Gráfico para entender a relação entre peso e altura dos pokémons
plt.figure(figsize=(6,5))
plt.title('Relação entre peso e altura dos pokémons')
plt.xlabel('Peso em quilos')
plt.ylabel('Altura em metros')
sns.scatterplot(x=df['peso kg'], y=df['altura m'], data=df)
# Out:
# <Axes: title={'center': 'Relação entre peso e altura dos pokémons'}, xlabel='Peso em quilos', ylabel='Altura em metros'>

# %%
# Relação entre peso e altura dos pokémons
# Gráfico para entender a relação entre peso e altura dos pokémons
df['taxa de captura'] = df['taxa de captura'].astype('float64') # convertendo o tipo de dados da coluna
plt.figure(figsize=(6,8))
plt.xlabel('Total dos atributos')
plt.ylabel('Taxa de captura')
plt.title('Relação entre soma dos atributos e taxa de captura')
sns.scatterplot(x=df['total atr'], y=df['taxa de captura'], data=df)
# Out:
# <Axes: title={'center': 'Relação entre soma dos atributos e taxa de captura'}, xlabel='Total dos atributos', ylabel='Taxa de captura'>

# %%
# Quantidades de pokémons por tipo
# Gráfico para descobrir quais tipos de pokemon possuem uma quantidade maior.
df_atributos = df[['nome', 'tipo 1', 'vida', 'ataque', 'defesa', 'sp ataque', 'sp defesa']]
titulo = 'Tipois de pokémons e atributos'
label_x = 'Tipos de pokémons'
label_y = 'Atributos do pokémon separados por cor'

plt.figure(figsize=(17, 8))
plt.title(titulo)
plt.xlabel(label_x)
plt.ylabel(label_y)
plt.bar(df_atributos['tipo 1'], df_atributos['vida'], color='#F24B78', label='vida')
plt.bar(df_atributos['tipo 1'], df_atributos['ataque'], color='#966BF2', label='ataque')
plt.bar(df_atributos['tipo 1'], df_atributos['defesa'], color='#F28705', label='defesa')
plt.bar(df_atributos['tipo 1'], df_atributos['sp ataque'], color='#1C98A6', label='sp ataque')
plt.bar(df_atributos['tipo 1'], df_atributos['sp defesa'], color='#F2E205', label='sp defesa')
plt.legend(title='Legenda', loc='upper right', fontsize='large')
plt.show()
# df_atributos

# %% [markdown]
# # Exportando arquivo final

# %%
df.to_csv('Pokemon_dataset_analisis.csv', index=False)
